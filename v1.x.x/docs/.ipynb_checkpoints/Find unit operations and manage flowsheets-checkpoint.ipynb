# %% [markdown]
# # Find unit operations and manage flowsheets

# %% [markdown]
# ### Retrieve any Unit, Stream or System object by ID

# %% [markdown]
# `find` has access to Flowsheet objects where all BioSTEAM objects are registered. The main flowsheet defaults to the 'Default' flowsheet:

# %%
import biosteam as bst
bst.find
# Out:
# <MainFlowsheet: Default>

# %% [markdown]
# Find a Unit object:

# %%
bs.Stream.species = bst.Species('Water', 'Ethanol')
unit = bst.units.Mixer('M0')
bst.find('M0')
# Out:
# Mixer: M0
# ins...
# [0] missing stream
# [1] missing stream
# outs...
# [0] d1
#     phase: 'l', T: 298.15 K, P: 101325 Pa
#     flow: 0

# %% [markdown]
# Find a Stream object:

# %%
bst.find('d1')
# Out:
# Stream: d1  from  Mixer-M0
#  phase: 'l', T: 298.15 K, P: 101325 Pa
#  flow: 0

# %% [markdown]
# All Unit objects can be viewed as a diagram:

# %%
bst.units.Mixer('M1')
bst.find.diagram()

# %% [markdown]
# All Stream, Unit, and System objects are stored as Register objects in `find`:

# %%
bst.find.stream
# Out:
# Register:
#  <Stream: d1>
#  <Stream: d2>

# %%
bst.find.unit
# Out:
# Register:
#  <Mixer: M0>
#  <Mixer: M1>

# %%
bst.find.system
# Out:
# Register: (Empty)

# %% [markdown]
# Access items in a register:

# %%
bst.find.unit.M0
# Out:
# Mixer: M0
# ins...
# [0] missing stream
# [1] missing stream
# outs...
# [0] d1
#     phase: 'l', T: 298.15 K, P: 101325 Pa
#     flow: 0

# %% [markdown]
# ### Switch between flowsheets

# %% [markdown]
# A new flowsheet may be created and set as the main flowsheet:

# %%
bst.find.set_flowsheet(bs.Flowsheet('New flowsheet'))
bst.find
# Out:
# <MainFlowsheet: New flowsheet>

# %% [markdown]
# Now all new objects will be registered in the new flowsheet:

# %%
unit = bs.units.Mixer('M2')
bst.find.diagram()

# %% [markdown]
# Note that objects in the original flowsheet are not defined anymore and searching them would raise an error:

# %%
bst.find('M0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-503e10b7cb09> in <module>()
# ----> 1 bs.find('M0')
#
# ~\OneDrive\Code\biosteam\biosteam\_flowsheet.py in __call__(self, ID)
#     249                or search_register(self.unit, ID)
#     250                or search_register(self.system, ID))
# --> 251         if not obj: raise ValueError(f"no registered item '{ID}'")
#     252         return obj
#     253
#
# ValueError: no registered item 'M0'

# %% [markdown]
# All Flowsheet objects are added to the `flowsheet` registry. Switching between flowsheets is easy:

# %%
bst.find.set_flowsheet(bs.find.flowsheet['Default']) # Switch back to default flowsheet
bst.find
# Out:
# <MainFlowsheet: Default>

# %% [markdown]
# As an example, the `lipidcane` biorefinery defines its own flowsheet and leaves it as the main flowsheet when you import it:

# %%
import lipidcane # You must pip install lipidcane first
bst.find
# Out:
# <MainFlowsheet: Lipidcane>

# %%
bst.find.diagram()
