# %%
from biosteam import Species, Stream, Flash
Stream.species = Species(['Water', 'Ethanol'])

# %%
feed = Stream('feed',
              flow=[400, 400], # kmol/hr
              T=298.15, # Kelvin
              P=101325) # Pascal

# %%
F1 = Flash('F1',
           ins=feed, # Input streams
           outs=('vap', 'liq'), # Output streams
           V=0.5, P=101325) 
F1.simulate()
F1.results.table()
# Out:
# Flash            Units        F1
# Design:
#   SepType               Vertical
#   Length            ft      14.5
#   Diameter          ft       6.5
#   Weight            lb  5.62e+03
#   Wall thickness    in     0.375
# Cost:
#   Vessel           USD  4.47e+04
#   Heat exchanger   USD   2.1e+04
