# %% [markdown]
# # Techno-economic analysis of a biorefinery

# %% [markdown]
# ### Perform cash flow analysis

# %% [markdown]
# Create a TEA object from a system:

# %%
import biosteam as bs
import lipidcane as lc

lc.lipidcane_sys.simulate()
lipidcane_tea = bs.TEA(lc.lipidcane_sys)
lipidcane_tea.show() # Show key results
# Out:
# TEA: lipid_cane_system
#  NPV: 1.34e+08 USD at 15.0% IRR
#  ROI: 0.2 1/yr
#  PBP: 3.84 yr

# %% [markdown]
# TEA objects have a long list of options for cash flow analysis:

# %%
lipidcane_tea.options
# Out:
# {'Lang factor': 4.37,
#  'Operating days': 330,
#  'IRR': 0.15,
#  'Wage': 50000.0,
#  'Year': None,
#  'Employees': 50,
#  'Fringe benefits': 0.4,
#  'Income tax': 0.35,
#  'Property tax': 0.001,
#  'Property insurance': 0.005,
#  'Duration': 20,
#  'Supplies': 0.2,
#  'Maintenance': 0.01,
#  'Administration': 0.005,
#  'Working capital': 0.05,
#  'Startup': 0,
#  'Land': 0,
#  'Royalties': 0,
#  'Depreciation': 'MACRS7',
#  'Startup schedule': (0.4, 0.6),
#  'Other recurring costs': 0,
#  'Other fixed capital': 0}

# %% [markdown]
# Update options and run cash flow analysis:

# %%
options = {'IRR': 0.175,
           'Lang factor': 3.00,
           'Operating days': 200,
           'Year': 2020,
           'Employees': 50,
           'Administration': 0.005,
           'Duration': 20}
lipidcane_tea.options.update(options)
lipidcane_tea.show()
# Out:
# TEA: lipid_cane_system
#  NPV: 3.17e+07 USD at 17.5% IRR
#  ROI: 0.166 1/yr
#  PBP: 4.45 yr

# %% [markdown]
# Retrieve general results:

# %%
lipidcane_tea.results()
# Out:
#                            Units     Value
# Depreciable capital          USD  1.74e+08
# Fixed capital investment     USD  1.74e+08
# Working capital              USD  8.72e+06
# Total capital investment     USD  1.83e+08
# Depreciation              USD/yr  8.72e+06
# Utility cost              USD/yr -1.49e+07
# Material cost             USD/yr   6.2e+07
# Sales                     USD/yr   1.1e+08
# Labor                     USD/yr   2.5e+06
# Annual operating cost     USD/yr  6.35e+07
# Net present value            USD  3.17e+07
# Return on investment        1/yr     0.166
# Pay back period               yr      4.45

# %% [markdown]
# The complete cashflow analysis is stored as a DataFrame object:

# %%
lipidcane_tea.cashflow
# Out:
#       Depreciable capital  Depreciation  Fixed capital  Working capital  \
# 2020             6.97e+07             0       6.97e+07                0
# 2021             1.05e+08             0       1.05e+08                0
# 2022                    0      2.49e+07              0         8.72e+06
# 2023                    0      4.27e+07              0                0
# 2024                    0      3.05e+07              0                0
# 2025                    0      2.18e+07              0                0
# 2026                    0      1.56e+07              0                0
# 2027                    0      1.56e+07              0                0
# 2028                    0      1.56e+07              0                0
# 2029                    0      7.78e+06              0                0
# 2030                    0             0              0                0
# 2031                    0             0              0                0
# 2032                    0             0              0                0
# 2033                    0             0              0                0
# 2034                    0             0              0                0
# 2035                    0             0              0                0
# 2036                    0             0              0                0
# 2037                    0             0              0                0
# 2038                    0             0              0                0
# 2039                    0             0              0        -8.72e+06
#
#       Annual operating cost (excl. depr.)   Sales  Net earnings  Cash flow  \
# 2020                                   0        0             0  -6.97e+07
# 2021                                   0        0             0  -1.05e+08
# 2022                            5.48e+07  1.1e+08      1.99e+07   3.61e+07
# 2023                            5.48e+07  1.1e+08      8.33e+06    5.1e+07
# 2024                            5.48e+07  1.1e+08      1.63e+07   4.68e+07
# 2025                            5.48e+07  1.1e+08      2.19e+07   4.37e+07
# 2026                            5.48e+07  1.1e+08       2.6e+07   4.15e+07
# 2027                            5.48e+07  1.1e+08       2.6e+07   4.15e+07
# 2028                            5.48e+07  1.1e+08       2.6e+07   4.15e+07
# 2029                            5.48e+07  1.1e+08       3.1e+07   3.88e+07
# 2030                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2031                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2032                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2033                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2034                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2035                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2036                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2037                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2038                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2039                            5.48e+07  1.1e+08      3.61e+07   4.48e+07
#
#       Discounted cash flow  Cumulative cash flow
# 2020             -6.97e+07             -6.97e+07
# 2021              -8.9e+07             -1.59e+08
# 2022              2.61e+07             -1.33e+08
# 2023              3.15e+07             -1.01e+08
# 2024              2.45e+07             -7.66e+07
# 2025              1.95e+07             -5.71e+07
# 2026              1.58e+07             -4.13e+07
# 2027              1.34e+07             -2.79e+07
# 2028              1.14e+07             -1.65e+07
# 2029              9.09e+06             -7.39e+06
# 2030              7.19e+06                -2e+05
# 2031              6.12e+06              5.92e+06
# 2032              5.21e+06              1.11e+07
# 2033              4.43e+06              1.56e+07
# 2034              3.77e+06              1.93e+07
# 2035              3.21e+06              2.26e+07
# 2036              2.73e+06              2.53e+07
# 2037              2.33e+06              2.76e+07
# 2038              1.98e+06              2.96e+07
# 2039              2.09e+06              3.17e+07

# %% [markdown]
# ### Find production cost, price, and IRR

# %% [markdown]
# Find production cost:

# %%
lipidcane_tea.production_cost(bs.find('Ethanol'), bs.find('Biodiesel'))# USD/yr
# Out:
# array([26492933.566, 37012550.153])

# %% [markdown]
# Solve for the price of a stream at the break even point:

# %%
feed = bs.find('Lipid cane')
lipidcane_tea.solve_price(feed) # USD/kg
# Out:
# 0.04117789345272506

# %% [markdown]
# Solve for the IRR at the break even point:

# %%
lipidcane_tea.options['IRR'] = lipidcane_tea.solve_IRR()
lipidcane_tea.show()
# Out:
# TEA: lipid_cane_system
#  NPV: 3.06 USD at 21.4% IRR
#  ROI: 0.166 1/yr
#  PBP: 4.45 yr

# %% [markdown]
# Note that the cashflow table will update itself:

# %%
lipidcane_tea.cashflow
# Out:
#       Depreciable capital  Depreciation  Fixed capital  Working capital  \
# 2020             6.97e+07             0       6.97e+07                0
# 2021             1.05e+08             0       1.05e+08                0
# 2022                    0      2.49e+07              0         8.72e+06
# 2023                    0      4.27e+07              0                0
# 2024                    0      3.05e+07              0                0
# 2025                    0      2.18e+07              0                0
# 2026                    0      1.56e+07              0                0
# 2027                    0      1.56e+07              0                0
# 2028                    0      1.56e+07              0                0
# 2029                    0      7.78e+06              0                0
# 2030                    0             0              0                0
# 2031                    0             0              0                0
# 2032                    0             0              0                0
# 2033                    0             0              0                0
# 2034                    0             0              0                0
# 2035                    0             0              0                0
# 2036                    0             0              0                0
# 2037                    0             0              0                0
# 2038                    0             0              0                0
# 2039                    0             0              0        -8.72e+06
#
#       Annual operating cost (excl. depr.)   Sales  Net earnings  Cash flow  \
# 2020                                   0        0             0  -6.97e+07
# 2021                                   0        0             0  -1.05e+08
# 2022                            5.48e+07  1.1e+08      1.99e+07   3.61e+07
# 2023                            5.48e+07  1.1e+08      8.33e+06    5.1e+07
# 2024                            5.48e+07  1.1e+08      1.63e+07   4.68e+07
# 2025                            5.48e+07  1.1e+08      2.19e+07   4.37e+07
# 2026                            5.48e+07  1.1e+08       2.6e+07   4.15e+07
# 2027                            5.48e+07  1.1e+08       2.6e+07   4.15e+07
# 2028                            5.48e+07  1.1e+08       2.6e+07   4.15e+07
# 2029                            5.48e+07  1.1e+08       3.1e+07   3.88e+07
# 2030                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2031                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2032                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2033                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2034                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2035                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2036                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2037                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2038                            5.48e+07  1.1e+08      3.61e+07   3.61e+07
# 2039                            5.48e+07  1.1e+08      3.61e+07   4.48e+07
#
#       Discounted cash flow  Cumulative cash flow
# 2020             -6.97e+07             -6.97e+07
# 2021             -8.62e+07             -1.56e+08
# 2022              2.45e+07             -1.31e+08
# 2023              2.85e+07             -1.03e+08
# 2024              2.15e+07             -8.13e+07
# 2025              1.66e+07             -6.48e+07
# 2026               1.3e+07             -5.18e+07
# 2027              1.07e+07             -4.11e+07
# 2028              8.81e+06             -3.23e+07
# 2029              6.78e+06             -2.55e+07
# 2030               5.2e+06             -2.03e+07
# 2031              4.28e+06              -1.6e+07
# 2032              3.53e+06             -1.25e+07
# 2033              2.91e+06             -9.56e+06
# 2034              2.39e+06             -7.17e+06
# 2035              1.97e+06              -5.2e+06
# 2036              1.63e+06             -3.57e+06
# 2037              1.34e+06             -2.23e+06
# 2038               1.1e+06             -1.13e+06
# 2039              1.13e+06                  3.06

# %% [markdown]
# ### System report

# %% [markdown]
# Save stream tables, utility requirements, itemized costs, TEA results, and a cash flow table:

# %%
lc.lipidcane_sys.save_report('Lipidcane report.xlsx') # Try this on your computer and open excel
