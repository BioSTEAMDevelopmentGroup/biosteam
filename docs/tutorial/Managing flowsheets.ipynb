# %% [markdown]
# # Managing flowsheets

# %% [markdown]
# ### Retrieve any Unit, Stream or System object by ID

# %% [markdown]
# All BioSTEAM objects are registered in the main flowsheet. When BioSTEAM is first imported, the main flowsheet defaults to the 'default' flowsheet:

# %%
from biosteam import main_flowsheet, settings, units
main_flowsheet
# Out:
# <MainFlowsheet: default>

# %% [markdown]
# Find a Unit object:

# %%
settings.set_thermo(['Water', 'Ethanol'])
unit = units.Mixer('M1')
main_flowsheet('M1')
# Out:
# Mixer: M1
# ins...
# [0] missing stream
# [1] missing stream
# outs...
# [0] s1
#     phase: 'l', T: 298.15 K, P: 101325 Pa
#     flow: 0

# %% [markdown]
# Find a Stream object:

# %%
main_flowsheet('s1')
# Out:
# Stream: s1 from <Mixer: M1>
#  phase: 'l', T: 298.15 K, P: 101325 Pa
#  flow: 0

# %% [markdown]
# All Unit objects can be viewed as a diagram:

# %%
units.Mixer('M2')
main_flowsheet.diagram()

# %% [markdown]
# All Stream, Unit, and System objects are stored as Register objects in `find`:

# %%
main_flowsheet.stream
# Out:
# Register:
#  <Stream: s1>
#  <Stream: s2>

# %%
main_flowsheet.unit
# Out:
# Register:
#  <Mixer: M1>
#  <Mixer: M2>

# %%
main_flowsheet.system
# Out:
# Register: (Empty)

# %% [markdown]
# Access items in a register:

# %%
main_flowsheet.unit.M1
# Out:
# Mixer: M1
# ins...
# [0] missing stream
# [1] missing stream
# outs...
# [0] s1
#     phase: 'l', T: 298.15 K, P: 101325 Pa
#     flow: 0

# %% [markdown]
# ### Switch between flowsheets

# %% [markdown]
# A new flowsheet may be created and set as the main flowsheet:

# %%
main_flowsheet.set_flowsheet('new_flowsheet')
main_flowsheet
# Out:
# <MainFlowsheet: new_flowsheet>

# %% [markdown]
# Now all new objects will be registered in the new flowsheet:

# %%
unit = units.Mixer('M3')
main_flowsheet.diagram()

# %% [markdown]
# Note that objects in the original flowsheet are not defined anymore and searching them would raise an error:

# %%
main_flowsheet('M1')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-11-48b9bbf4ed05> in <module>
# ----> 1 main_flowsheet('M1')
#
# ~\OneDrive\Code\biosteam\biosteam\_flowsheet.py in __call__(self, ID)
#     273                or self.unit.search(ID)
#     274                or self.system.search(ID))
# --> 275         if not obj: raise LookupError(f"no registered item '{ID}'")
#     276         return obj
#     277
#
# LookupError: no registered item 'M1'

# %% [markdown]
# All Flowsheet objects are added to the `flowsheet` registry. Switching between flowsheets is easy:

# %%
main_flowsheet.set_flowsheet('default') # Switch back to default flowsheet
main_flowsheet
# Out:
# <MainFlowsheet: default>

# %% [markdown]
# As an example, the `lipidcane` biorefinery defines its own flowsheet and leaves it as the main flowsheet when you import it:

# %%
from biorefineries.lipidcane import system
main_flowsheet
# Out:
# <MainFlowsheet: lipidcane>

# %%
main_flowsheet.system.lipidcane_sys.diagram('thorough')
