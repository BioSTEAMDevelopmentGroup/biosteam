# %% [markdown]
# # Techno-economic analysis of a biorefinery

# %% [markdown]
# ### Perform cash flow analysis

# %% [markdown]
# Create a TEA object from a system:

# %%
import biosteam as bst
import lipidcane as lc

lc.lipidcane_sys.simulate()
lipidcane_tea = bst.TEA(lc.lipidcane_sys)
lipidcane_tea.show() # Print TEA summary at current options
# Out:
# TEA: lipid_cane_system
#  NPV: 2.09e+08 USD at 15.0% IRR
#  ROI: 0.3 1/yr
#  PBP: 2.74 yr

# %% [markdown]
# TEA objects have a long list of options for cash flow analysis:

# %%
lipidcane_tea.options
# Out:
# {'Lang factor': 3,
#  'Operating days': 330,
#  'IRR': 0.15,
#  'Wage': 50000.0,
#  'Year': None,
#  'Employees': 50,
#  'Fringe benefits': 0.4,
#  'Income tax': 0.35,
#  'Property tax': 0.001,
#  'Property insurance': 0.005,
#  'Duration': 20,
#  'Supplies': 0.2,
#  'Maintenance': 0.01,
#  'Administration': 0.005,
#  'Working capital': 0.05,
#  'Startup': 0,
#  'Land': 0,
#  'Royalties': 0,
#  'Contingency': 0.18,
#  'Depreciation': 'MACRS7',
#  'Startup schedule': (0.4, 0.6),
#  'Other recurring costs': 0,
#  'Other fixed capital': 0}

# %% [markdown]
# Update options and retrieve results from cash flow analysis:

# %%
options = {'IRR': 0.175,
           'Lang factor': 3.00,
           'Operating days': 200,
           'Year': 2020,
           'Employees': 50,
           'Administration': 0.005,
           'Duration': 20}
lipidcane_tea.options.update(options)
lipidcane_tea.results()
# Out:
#                            Units     Value
# Depreciable capital          USD  1.93e+08
# Fixed capital investment     USD  1.93e+08
# Working capital              USD  9.63e+06
# Total capital investment     USD  2.02e+08
# Depreciation              USD/yr  9.63e+06
# Utility cost              USD/yr -2.71e+07
# Material cost             USD/yr  6.16e+07
# Sales                     USD/yr  1.02e+08
# Labor                     USD/yr   2.5e+06
# Annual operating cost     USD/yr  5.22e+07
# Net present value            USD  2.85e+07
# Return on investment        1/yr     0.159
# Pay back period               yr      4.61

# %% [markdown]
# Retrieve complete cashflow analysis as a DataFrame object:

# %%
lipidcane_tea.get_cashflow()
# Out:
#       Depreciable capital  Depreciation  Fixed capital  Working capital  \
# 2020             7.71e+07             0       7.71e+07                0
# 2021             1.16e+08             0       1.16e+08                0
# 2022                    0      2.75e+07              0         9.63e+06
# 2023                    0      4.72e+07              0                0
# 2024                    0      3.37e+07              0                0
# 2025                    0      2.41e+07              0                0
# 2026                    0      1.72e+07              0                0
# 2027                    0      1.72e+07              0                0
# 2028                    0      1.72e+07              0                0
# 2029                    0      8.59e+06              0                0
# 2030                    0             0              0                0
# 2031                    0             0              0                0
# 2032                    0             0              0                0
# 2033                    0             0              0                0
# 2034                    0             0              0                0
# 2035                    0             0              0                0
# 2036                    0             0              0                0
# 2037                    0             0              0                0
# 2038                    0             0              0                0
# 2039                    0             0              0        -9.63e+06
#
#       Annual operating cost (excl. depr.)    Sales  Net earnings  Cash flow  \
# 2020                                   0         0             0  -7.71e+07
# 2021                                   0         0             0  -1.16e+08
# 2022                            4.26e+07  1.02e+08      2.06e+07   3.85e+07
# 2023                            4.26e+07  1.02e+08      7.79e+06    5.5e+07
# 2024                            4.26e+07  1.02e+08      1.66e+07   5.03e+07
# 2025                            4.26e+07  1.02e+08      2.28e+07   4.69e+07
# 2026                            4.26e+07  1.02e+08      2.73e+07   4.45e+07
# 2027                            4.26e+07  1.02e+08      2.73e+07   4.45e+07
# 2028                            4.26e+07  1.02e+08      2.73e+07   4.45e+07
# 2029                            4.26e+07  1.02e+08      3.29e+07   4.15e+07
# 2030                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2031                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2032                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2033                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2034                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2035                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2036                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2037                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2038                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2039                            4.26e+07  1.02e+08      3.85e+07   4.81e+07
#
#       Discounted cash flow  Cumulative cash flow
# 2020             -7.71e+07             -7.71e+07
# 2021             -9.84e+07             -1.75e+08
# 2022              2.79e+07             -1.48e+08
# 2023              3.39e+07             -1.14e+08
# 2024              2.64e+07             -8.74e+07
# 2025              2.09e+07             -6.64e+07
# 2026              1.69e+07             -4.95e+07
# 2027              1.44e+07             -3.51e+07
# 2028              1.22e+07             -2.29e+07
# 2029              9.71e+06             -1.32e+07
# 2030              7.67e+06             -5.51e+06
# 2031              6.53e+06              1.02e+06
# 2032              5.55e+06              6.57e+06
# 2033              4.73e+06              1.13e+07
# 2034              4.02e+06              1.53e+07
# 2035              3.42e+06              1.87e+07
# 2036              2.91e+06              2.17e+07
# 2037              2.48e+06              2.41e+07
# 2038              2.11e+06              2.63e+07
# 2039              2.25e+06              2.85e+07

# %% [markdown]
# ### Find production cost, price, and IRR

# %% [markdown]
# Find production cost:

# %%
lipidcane_tea.production_cost(bst.find('Ethanol'), bst.find('Biodiesel'))# USD/yr
# Out:
# array([22349632.744, 29879831.68 ])

# %% [markdown]
# Solve for the price of a stream at the break even point:

# %%
feed = bst.find('Lipid cane')
lipidcane_tea.solve_price(feed) # USD/kg
# Out:
# 0.04051119454207958

# %% [markdown]
# Solve for the IRR at the break even point:

# %%
lipidcane_tea.options['IRR'] = lipidcane_tea.solve_IRR()
lipidcane_tea.show()
# Out:
# TEA: lipid_cane_system
#  NPV: 8.14e-06 USD at 20.7% IRR
#  ROI: 0.159 1/yr
#  PBP: 4.61 yr

# %% [markdown]
# Note that the cashflow table is always created up to date:

# %%
lipidcane_tea.get_cashflow()
# Out:
#       Depreciable capital  Depreciation  Fixed capital  Working capital  \
# 2020             7.71e+07             0       7.71e+07                0
# 2021             1.16e+08             0       1.16e+08                0
# 2022                    0      2.75e+07              0         9.63e+06
# 2023                    0      4.72e+07              0                0
# 2024                    0      3.37e+07              0                0
# 2025                    0      2.41e+07              0                0
# 2026                    0      1.72e+07              0                0
# 2027                    0      1.72e+07              0                0
# 2028                    0      1.72e+07              0                0
# 2029                    0      8.59e+06              0                0
# 2030                    0             0              0                0
# 2031                    0             0              0                0
# 2032                    0             0              0                0
# 2033                    0             0              0                0
# 2034                    0             0              0                0
# 2035                    0             0              0                0
# 2036                    0             0              0                0
# 2037                    0             0              0                0
# 2038                    0             0              0                0
# 2039                    0             0              0        -9.63e+06
#
#       Annual operating cost (excl. depr.)    Sales  Net earnings  Cash flow  \
# 2020                                   0         0             0  -7.71e+07
# 2021                                   0         0             0  -1.16e+08
# 2022                            4.26e+07  1.02e+08      2.06e+07   3.85e+07
# 2023                            4.26e+07  1.02e+08      7.79e+06    5.5e+07
# 2024                            4.26e+07  1.02e+08      1.66e+07   5.03e+07
# 2025                            4.26e+07  1.02e+08      2.28e+07   4.69e+07
# 2026                            4.26e+07  1.02e+08      2.73e+07   4.45e+07
# 2027                            4.26e+07  1.02e+08      2.73e+07   4.45e+07
# 2028                            4.26e+07  1.02e+08      2.73e+07   4.45e+07
# 2029                            4.26e+07  1.02e+08      3.29e+07   4.15e+07
# 2030                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2031                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2032                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2033                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2034                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2035                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2036                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2037                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2038                            4.26e+07  1.02e+08      3.85e+07   3.85e+07
# 2039                            4.26e+07  1.02e+08      3.85e+07   4.81e+07
#
#       Discounted cash flow  Cumulative cash flow
# 2020             -7.71e+07             -7.71e+07
# 2021             -9.58e+07             -1.73e+08
# 2022              2.64e+07             -1.46e+08
# 2023              3.13e+07             -1.15e+08
# 2024              2.37e+07             -9.15e+07
# 2025              1.83e+07             -7.32e+07
# 2026              1.44e+07             -5.88e+07
# 2027              1.19e+07             -4.68e+07
# 2028              9.89e+06             -3.69e+07
# 2029              7.64e+06             -2.93e+07
# 2030              5.87e+06             -2.34e+07
# 2031              4.87e+06             -1.86e+07
# 2032              4.03e+06             -1.45e+07
# 2033              3.34e+06             -1.12e+07
# 2034              2.77e+06             -8.43e+06
# 2035              2.29e+06             -6.13e+06
# 2036               1.9e+06             -4.23e+06
# 2037              1.58e+06             -2.66e+06
# 2038              1.31e+06             -1.35e+06
# 2039              1.35e+06              8.15e-06

# %% [markdown]
# ### System report

# %% [markdown]
# Save stream tables, utility requirements, itemized costs, TEA results, and a cash flow table:

# %%
lc.lipidcane_sys.save_report('Lipidcane report.xlsx') # Try this on your computer and open excel
